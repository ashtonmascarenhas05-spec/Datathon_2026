# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/ChargesheetDetails.csv')

# %%
df.head()
# Out:
#    CSID  CaseMasterID               csdate cstype  PolicePersonID
# 0     1             1  2026-03-02 07:08:00      A             786
# 1     2             2  2026-03-06 17:05:00      A             865
# 2     3             3  2024-02-04 16:38:00      B            1363
# 3     4             4  2025-05-13 22:41:00      A             970
# 4     5             5  2022-12-06 00:48:00      A             877

# %%
df.tail()
# Out:
#         CSID  CaseMasterID               csdate cstype  PolicePersonID
# 13223  13224         14996  2022-04-13 05:08:00      B             977
# 13224  13225         14997  2025-04-25 23:42:00      A             954
# 13225  13226         14998  2025-02-05 19:15:00      A             973
# 13226  13227         14999  2021-12-12 05:30:00      C            1114
# 13227  13228         15000  2024-10-16 18:51:00      A            1061

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13228 entries, 0 to 13227
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CSID            13228 non-null  int64
#  1   CaseMasterID    13228 non-null  int64
#  2   csdate          13228 non-null  object
#  3   cstype          13228 non-null  object
#  4   PolicePersonID  13228 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 516.8+ KB

# %%
df.isnull().sum()
# Out:
# CSID              0
# CaseMasterID      0
# csdate            0
# cstype            0
# PolicePersonID    0
# dtype: int64

# %%
df.describe()
# Out:
#                CSID  CaseMasterID  PolicePersonID
# count  13228.000000  13228.000000    13228.000000
# mean    6614.500000   7508.509223     1026.198140
# std     3818.739015   4326.110944      230.406298
# min        1.000000      1.000000      683.000000
# 25%     3307.750000   3769.750000      859.000000
# 50%     6614.500000   7501.500000      974.000000
# 75%     9921.250000  11254.500000     1153.000000
# max    13228.000000  15000.000000     1705.000000

# %%
df.shape
# Out:
# (13228, 5)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["CaseMasterID"].nunique()
# Out:
# 13228

# %%
df["cstype"].value_counts()
# Out:
# cstype
# A    10829
# C     1475
# B      924
# Name: count, dtype: int64

# %%
df["cstype"].value_counts(normalize=True)*100
# Out:
# cstype
# A    81.864227
# C    11.150590
# B     6.985183
# Name: proportion, dtype: float64

# %%
df["csdate"] = pd.to_datetime(df["csdate"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13228 entries, 0 to 13227
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CSID            13228 non-null  int64
#  1   CaseMasterID    13228 non-null  int64
#  2   csdate          13228 non-null  datetime64[ns]
#  3   cstype          13228 non-null  object
#  4   PolicePersonID  13228 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 516.8+ KB

# %%
df["Year"] = df["csdate"].dt.year
df["Month"] = df["csdate"].dt.month
df["Day"] = df["csdate"].dt.day
df["Hour"] = df["csdate"].dt.hour

# %%
df.head()
# Out:
#    CSID  CaseMasterID              csdate cstype  PolicePersonID  Year  Month  \
# 0     1             1 2026-03-02 07:08:00      A             786  2026      3
# 1     2             2 2026-03-06 17:05:00      A             865  2026      3
# 2     3             3 2024-02-04 16:38:00      B            1363  2024      2
# 3     4             4 2025-05-13 22:41:00      A             970  2025      5
# 4     5             5 2022-12-06 00:48:00      A             877  2022     12
#
#    Day  Hour
# 0    2     7
# 1    6    17
# 2    4    16
# 3   13    22
# 4    6     0

# %%
(df["PolicePersonID"] <= 0).sum()
# Out:
# np.int64(0)

# %%
print(df["csdate"].min())
print(df["csdate"].max())
# Out:
# 2021-01-17 11:06:00
# 2026-07-20 16:53:00

# %%
df.drop(columns=["Year", "Month", "Day", "Hour"], inplace=True)

# %%
df.to_csv("chargesheet_cleaned.csv", index=False)
